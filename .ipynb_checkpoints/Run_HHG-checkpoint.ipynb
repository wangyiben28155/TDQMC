# %%
include("Main_module.jl")
using .TDQMC

# %%
using DataFrames, CSV, PyPlot

# %%
df = CSV.read("Ground_Guide_Wave.csv", DataFrame)
tr = Matrix(CSV.read("Ground_Trajectory.csv", DataFrame))
# Out:
# 1×500 Matrix{Float64}:
#  0.175251  0.698886  -1.09586  3.41988  …  0.711265  0.973121  -0.797173

# %%
Electron_num = size(tr, 1)
Ensemble_num = size(tr, 2)
Total_num = Electron_num * Ensemble_num
# Out:
# 500

# %%
initial_range = df[:, Total_num+1];         #最后一列保存的是空间的离散信息
Raw_Array = reshape(complex(Matrix(@. abs(parse(Complex{Float64}, df[:, 1:Total_num])))), (3001, Electron_num, Ensemble_num));          # 500代表的是系综*电子数的数目,因为是单电子所以不需要reshape

# %%
s_range = initial_range[end]
s_num = length(initial_range)
# Out:
# 3001

# %%
l_range = 80.0
l_num = extend_num(s_range, l_range, s_num)
# Out:
# 8001

# %%
P = Parameter{Float64,Int64}(space_N = l_num, scope = l_range, Δt = 0.05, step_t = 5000)
# Out:
# Parameter{Float64, Int64}(1, 500, [1], 8001, 80.0, 0.02, 0.0008, range(-80.0, stop=80.0, length=8001), 0.05, 5000)

# %%
Raw_GuideWave = stitch_Matrix(Raw_Array, l_num)
# Out:
# 1×500 Matrix{Vector{ComplexF64}}:
#  [0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im  …  0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im]  …  [0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im  …  0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im, 0.0+0.0im]

# %%
Dy = Dynamics{Float64}(Trajectory = tr, Guide_Wave = Raw_GuideWave, Displace = zeros(eltype(tr), (P.step_t + 1, Ensemble_num, Electron_num)), Time = zeros(typeof(P.Δt), Ensemble_num));
df = nothing
Raw_DuideWave = nothing
Raw_Array = nothing
tr = nothing
GC.gc()
# Out:
# MethodError: no method matching zero(::Type{Any})
# Closest candidates are:
#   zero(::Type{Union{Missing, T}}) where T at C:\Users\86187\AppData\Local\Julia\Julia-1.7.2\share\julia\base\missing.jl:105
#   zero(::Union{Type{P}, P}) where P<:Dates.Period at C:\Users\86187\AppData\Local\Julia\Julia-1.7.2\share\julia\stdlib\v1.7\Dates\src\periods.jl:53
#   zero(::LinearAlgebra.Diagonal{T, StaticArrays.SVector{N, T}}) where {N, T} at C:\Users\86187\.julia\packages\StaticArrays\OWJK7\src\SDiagonal.jl:41
#   ...
#
# Stacktrace:
#  [1] zero(#unused#::Type{Any})
#    @ Base .\missing.jl:106
#  [2] zeros(#unused#::Type{Any}, dims::Tuple{Int64, Int64, Int64})
#    @ Base .\array.jl:526
#  [3] top-level scope
#    @ In[13]:1
#  [4] eval
#    @ .\boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
hist(Dy.Trajectory', 50, density = true);
plot(P.sampling, abs2.(Dy.Guide_Wave[1]), color = "red")      #说明长度能够吻合上
grid()
xlim(-10, 10)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall C:\Users\86187\.julia\packages\PyCall\3fwVL\src\numpy.jl:67
# (-10.0, 10.0)

# %%
parallel_Evolution!(P, Dy)

# %%
Dy.Displace = reshape(Matrix(CSV.read("Displace_Ensemble.csv", DataFrame))[:, 1:Ensemble_num], (10000+1, Ensemble_num, Electron_num))
# Out:
# 10001×500×1 Array{Float64, 3}:
# [:, :, 1] =
#  0.235243  0.554252  -0.939101    2.80733  …  0.821298  0.942939  -0.310769
#  0.235243  0.554252  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554252  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554252  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554252  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733  …  0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733  …  0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  0.235243  0.554251  -0.939101    2.80733     0.821298  0.942939  -0.310769
#  ⋮                                         ⋱
#  0.293166  0.693353  -1.34072   166.628       1.03738   1.20074   -0.410511
#  0.29741   0.691422  -1.34246   166.626    …  1.03248   1.19692   -0.409902
#  0.300757  0.689246  -1.34504   166.57        1.02755   1.19312   -0.408535
#  0.302919  0.68701   -1.34859   166.508       1.02314   1.18985   -0.406285
#  0.303685  0.684782  -1.35319   166.499       1.01975   1.18765   -0.403074
#  0.302957  0.682567  -1.35882   166.5         1.01775   1.18701   -0.39892
#  0.300763  0.680323  -1.36526   166.505    …  1.01737   1.1883    -0.393957
#  0.297275  0.677999  -1.37215   166.51        1.01863   1.19164   -0.388438
#  0.292799  0.675574  -1.37901   166.5         1.02143   1.19697   -0.382716
#  0.287753  0.673081  -1.38519   166.431       1.02554   1.20395   -0.377157
#  0.282618  0.670641  -1.39006   166.38        1.03062   1.21207   -0.372133
#  0.277869  0.668465  -1.3931    166.374    …  1.03629   1.22066   -0.367985

# %%
plot(real(P.Δt).* (0:10000), Dy.Displace[:, :, 1])
ylim(-l_range, l_range)
xlim(0, P.Δt * P.step_t)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (0.0, 15.0)

# %%
findall(x -> abs(x) >= 150, Dy.Displace[:, :, 1])
# Out:
# CartesianIndex{2}[]

# %%
plot(real(P.Δt).* (0:P.step_t), Dy.Displace[:, 4, 1])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000A26EB790>

# %%
#frequency, Total_ft_dipole, Total_ft_acc = HHG(P, Dy)
# Out:
# UndefVarError: Dy not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
semilogy(frequency, abs2.(Total_ft_dipole ./ (P.step_t * P.Δt)))
semilogy(frequency, abs2.(Total_ft_acc ./ (P.step_t * P.Δt)))
#xticks(0.05 * collect(0:2:20), collect(0:2:20))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall C:\Users\86187\.julia\packages\PyCall\3fwVL\src\numpy.jl:67
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000A42B5400>

# %%
semilogy(P.sampling, abs2.(Dy.Guide_Wave[3]), color = "red")      #说明长度能够吻合上
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000007FE07790>
